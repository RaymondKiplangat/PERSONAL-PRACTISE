# %%
import csv

import pandas as pd

from collections import Counter

import numpy as np

from  matplotlib import pyplot as plt

# %%
plt.style.use("fivethirtyeight")

# %%
#METHOD 1

# %%
data = pd.read_csv("C:/Users/Ray/Desktop/data.csv")

ids= data["Responder_id"]

lang_responses = data['LanguagesWorkedWith']

language_counter = Counter()

for response in lang_responses:
        language_counter.update(response.split(";"))
        

        
languages=[]
popularity=[]



for item in language_counter.most_common(15):
    languages.append(item[0])
    popularity.append(item[1])

    
print(languages)
print(popularity)



#reverse the bars comment the lines to see the difference.
languages.reverse()
popularity.reverse()



#plotting the bar-h (horizontal bar.)
plt.barh(languages, popularity)



#adding the title
plt.title("Most popular languages")




#labels
#plt.ylabel("Programming Languages")
plt.xlabel("Number of people who use")


plt.tight_layout()


#plotting the data
plt.show()
# Out:
# ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java', 'Bash/Shell/PowerShell', 'C#', 'PHP', 'C++', 'TypeScript', 'C', 'Other(s):', 'Ruby', 'Go', 'Assembly']
# [59219, 55466, 47544, 36443, 35917, 31991, 27097, 23030, 20524, 18523, 18017, 7920, 7331, 7201, 5833]

# %%
#METHOD 2

# %%
with open ("C:/Users/Ray/Desktop/data.csv") as csv_file:
    csv_reader = csv.DictReader(csv_file)
    
    language_counter = Counter()
    
    for row in csv_reader:
        language_counter.update(row['LanguagesWorkedWith'].split(";"))
        
        
languages=[]
popularity=[]



for item in language_counter.most_common(15):
    languages.append(item[0])
    popularity.append(item[1])

    
print(languages)
print(popularity)



#reverse the bars comment the lines to see the difference.
languages.reverse()
popularity.reverse()



#plotting the bar-h (horizontal bar.)
plt.barh(languages, popularity)



#adding the title
plt.title("Most popular languages")




#labels
#plt.ylabel("Programming Languages")
plt.xlabel("Number of people who use")


plt.tight_layout()


#plotting the data
plt.show()
# Out:
# ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java', 'Bash/Shell/PowerShell', 'C#', 'PHP', 'C++', 'TypeScript', 'C', 'Other(s):', 'Ruby', 'Go', 'Assembly']
# [59219, 55466, 47544, 36443, 35917, 31991, 27097, 23030, 20524, 18523, 18017, 7920, 7331, 7201, 5833]
